# %% [markdown]
# <div class="markdown-google-sans">
#   <h2>Machine Learning Hardware Course​</h2>
# </div>

# %% [markdown]
# <div class="markdown-google-sans">
#   <h2>Lab 4b: HW benchmarking</h2>
# </div>

# %% [markdown]
# Run the below code twice. One time using a CPU and the other one use a GPU. Before re-running the code for the different HW, record your results with this notebook TO AVOID LOSING YOUR PROGRESS!

# %%
from transformers import ViTFeatureExtractor, ViTForImageClassification
import torch
import torchvision.transforms as T
from PIL import Image
import requests
from torchvision import datasets, models
from tqdm import tqdm
import time

# Load an image from COCO dataset
url = 'http://images.cocodataset.org/val2017/000000039769.jpg'
image = Image.open(requests.get(url, stream=True).raw)

# Define preprocessing for AlexNet
transform = T.Compose([
    T.Resize((224, 224)),  # Resize to 224x224 as expected by AlexNet
    T.ToTensor(),
    T.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225]),  # Normalization for ImageNet
])

# Apply preprocessing
image = transform(image).unsqueeze(0)  # Add batch dimension

# %%
# Move to GPU/MPS if available
device, dev_name = (torch.device("mps"), "mps") if torch.backends.mps.is_available() else \
         (torch.device("cuda"), "cuda") if torch.cuda.is_available() else (torch.device("cpu"), "cpu")

# %%
def profile_workload(model, device, dev_name, image, iterations=100):
    try:
        model_name = type(model).__name__
        print(f"profiling {model_name} on {dev_name}...")
    except:
        print(f"profiling on {dev_name}...")
    model.to(device)
    image = image.to(device)

    # Run inference
    if dev_name=="cpu":
        start_time = time.time()
        for _ in tqdm(range(iterations), desc ='profiling latency is in progress...'):
            with torch.no_grad():
              output = model(image)
        elapsed_time = time.time()-start_time
        latency = elapsed_time/iterations*1000
    elif dev_name=="cuda":
        torch.cuda.synchronize()  # Ensure any pending tasks are done
        start = torch.cuda.Event(enable_timing=True)
        end = torch.cuda.Event(enable_timing=True)
        start.record()
        for _ in tqdm(range(iterations), desc ='profiling latency is in progress...'):
            with torch.no_grad():
              output = model(image)
        end.record()
        torch.cuda.synchronize()  # Wait for all kernels to finish
        latency = start.elapsed_time(end)/iterations
    elif dev_name=="mps":
        torch.mps.synchronize()  # Ensure all pending tasks are complete before starting
        start_time = time.time()
        for _ in tqdm(range(iterations), desc ='profiling latency is in progress...'):
            with torch.no_grad():
              output = model(image)
        elapsed_time = time.time()-start_time
        torch.mps.synchronize()  # Ensure all pending tasks are complete before starting
        latency = elapsed_time/iterations*1000
    # Get predicted class
    predicted_class = output.argmax(dim=1).item()
    # print(f"Predicted Class: {predicted_class}")
    return latency

# %%
def profile_workload_on_ViT(device, dev_name, iterations=100):
    # Load an image from COCO dataset
    url = 'http://images.cocodataset.org/val2017/000000039769.jpg'
    image = Image.open(requests.get(url, stream=True).raw)

    # Use ViTImageProcessor instead of the deprecated ViTFeatureExtractor
    processor = ViTImageProcessor.from_pretrained('google/vit-large-patch16-224')
    ViT_large = ViTForImageClassification.from_pretrained('google/vit-large-patch16-224')
    # Apply feature extractor directly on the raw image
    inputs = processor(images=image, return_tensors="pt")

    ViT_large.to(device)
    inputs = inputs.to(device)

    # Run inference
    if dev_name=="cpu":
        start_time = time.time()
        for _ in tqdm(range(iterations), desc ='profiling latency is in progress...'):
            with torch.no_grad():
              outputs = ViT_large(**inputs)
        elapsed_time = time.time()-start_time
        latency = elapsed_time/iterations*1000
    elif dev_name=="cuda":
        torch.cuda.synchronize()  # Ensure any pending tasks are done
        start = torch.cuda.Event(enable_timing=True)
        end = torch.cuda.Event(enable_timing=True)
        start.record()
        for _ in tqdm(range(iterations), desc ='profiling latency is in progress...'):
            with torch.no_grad():
              outputs = ViT_large(**inputs)
        end.record()
        torch.cuda.synchronize()  # Wait for all kernels to finish
        latency = start.elapsed_time(end)/iterations
    elif dev_name=="mps":
        torch.mps.synchronize()  # Ensure all pending tasks are complete before starting
        start_time = time.time()
        for _ in tqdm(range(iterations), desc ='profiling latency is in progress...'):
            with torch.no_grad():
              outputs = ViT_large(**inputs)
        elapsed_time = time.time()-start_time
        torch.mps.synchronize()  # Ensure all pending tasks are complete before starting
        latency = elapsed_time/iterations*1000
    # Get predicted class
    return latency

# %%
alexnet = torch.hub.load('pytorch/vision:v0.10.0', 'alexnet', pretrained=True)
alexnet_inference_latency = profile_workload(alexnet, device, dev_name, image, iterations=100)
print(f"\n\nAlexNet inference latency: {alexnet_inference_latency:.2f} ms")
# Out:
# Downloading: "https://github.com/pytorch/vision/zipball/v0.10.0" to /root/.cache/torch/hub/v0.10.0.zip
# /usr/local/lib/python3.11/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=AlexNet_Weights.IMAGENET1K_V1`. You can also use `weights=AlexNet_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Downloading: "https://download.pytorch.org/models/alexnet-owt-7be5be79.pth" to /root/.cache/torch/hub/checkpoints/alexnet-owt-7be5be79.pth
# 100%|██████████| 233M/233M [00:01<00:00, 135MB/s]
# profiling AlexNet on cpu...
# profiling latency is in progress...: 100%|██████████| 100/100 [00:08<00:00, 11.79it/s]
# AlexNet inference latency: 84.87 ms

# %%
resnet152 = torch.hub.load('pytorch/vision:v0.10.0', 'resnet152', pretrained=True)
resnet152_inference_latency = profile_workload(resnet152, device, dev_name, image, iterations=100)
print(f"\n\nResNet152 inference latency: {resnet152_inference_latency:.2f} ms")
# Out:
# Using cache found in /root/.cache/torch/hub/pytorch_vision_v0.10.0
# /usr/local/lib/python3.11/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet152_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet152_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Downloading: "https://download.pytorch.org/models/resnet152-394f9c45.pth" to /root/.cache/torch/hub/checkpoints/resnet152-394f9c45.pth
# 100%|██████████| 230M/230M [00:02<00:00, 112MB/s]
# profiling ResNet on cpu...
# profiling latency is in progress...: 100%|██████████| 100/100 [01:08<00:00,  1.47it/s]
# ResNet152 inference latency: 680.85 ms

# %%
from transformers import ViTImageProcessor, ViTForImageClassification
import torch
from PIL import Image
import requests

ViTLarge_inference_latency = profile_workload_on_ViT(device, dev_name, iterations=100)
print(f"\n\nViTLarge inference latency: {ViTLarge_inference_latency:.2f} ms")
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# preprocessor_config.json:   0%|          | 0.00/160 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/69.7k [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/1.22G [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/1.22G [00:00<?, ?B/s]
# profiling latency is in progress...:   0%|          | 0/100 [00:00<?, ?it/s]
# profiling latency is in progress...:   1%|          | 1/100 [00:05<08:42,  5.28s/it]
# profiling latency is in progress...:   2%|▏         | 2/100 [00:07<06:03,  3.71s/it]
# profiling latency is in progress...:   3%|▎         | 3/100 [00:13<07:11,  4.45s/it]
# profiling latency is in progress...:   4%|▍         | 4/100 [00:16<06:05,  3.81s/it]
# profiling latency is in progress...:   5%|▌         | 5/100 [00:18<05:14,  3.31s/it]
# profiling latency is in progress...:   6%|▌         | 6/100 [00:20<04:41,  3.00s/it]
# profiling latency is in progress...:   7%|▋         | 7/100 [00:24<04:43,  3.04s/it]
# profiling latency is in progress...:   8%|▊         | 8/100 [00:26<04:29,  2.93s/it]
# profiling latency is in progress...:   9%|▉         | 9/100 [00:29<04:11,  2.76s/it]
# profiling latency is in progress...:  10%|█         | 10/100 [00:31<03:57,  2.64s/it]
# profiling latency is in progress...:  11%|█         | 11/100 [00:33<03:48,  2.57s/it]
# profiling latency is in progress...:  12%|█▏        | 12/100 [00:37<04:08,  2.82s/it]
# profiling latency is in progress...:  13%|█▎        | 13/100 [00:39<03:57,  2.74s/it]
# profiling latency is in progress...:  14%|█▍        | 14/100 [00:42<03:46,  2.63s/it]
# profiling latency is in progress...:  15%|█▌        | 15/100 [00:44<03:37,  2.56s/it]
# profiling latency is in progress...:  16%|█▌        | 16/100 [00:47<03:32,  2.53s/it]
# profiling latency is in progress...:  17%|█▋        | 17/100 [00:50<03:53,  2.81s/it]
# profiling latency is in progress...:  18%|█▊        | 18/100 [00:53<03:43,  2.73s/it]
# profiling latency is in progress...:  19%|█▉        | 19/100 [00:55<03:35,  2.66s/it]
# profiling latency is in progress...:  20%|██        | 20/100 [00:58<03:30,  2.63s/it]
# profiling latency is in progress...:  21%|██        | 21/100 [01:00<03:29,  2.66s/it]
# profiling latency is in progress...:  22%|██▏       | 22/100 [01:04<03:42,  2.85s/it]
# profiling latency is in progress...:  23%|██▎       | 23/100 [01:06<03:31,  2.75s/it]
# profiling latency is in progress...:  24%|██▍       | 24/100 [01:09<03:23,  2.68s/it]
# profiling latency is in progress...:  25%|██▌       | 25/100 [01:11<03:19,  2.66s/it]
# profiling latency is in progress...:  26%|██▌       | 26/100 [01:15<03:31,  2.85s/it]
# profiling latency is in progress...:  27%|██▋       | 27/100 [01:17<03:24,  2.81s/it]
# profiling latency is in progress...:  28%|██▊       | 28/100 [01:20<03:15,  2.71s/it]
# profiling latency is in progress...:  29%|██▉       | 29/100 [01:22<03:09,  2.66s/it]
# profiling latency is in progress...:  30%|███       | 30/100 [01:25<03:03,  2.63s/it]
# profiling latency is in progress...:  31%|███       | 31/100 [01:28<03:18,  2.88s/it]
# profiling latency is in progress...:  32%|███▏      | 32/100 [01:31<03:07,  2.76s/it]
# profiling latency is in progress...:  33%|███▎      | 33/100 [01:33<03:00,  2.70s/it]
# profiling latency is in progress...:  34%|███▍      | 34/100 [01:36<03:04,  2.80s/it]
# profiling latency is in progress...:  35%|███▌      | 35/100 [01:40<03:14,  2.99s/it]
# profiling latency is in progress...:  36%|███▌      | 36/100 [01:43<03:06,  2.92s/it]
# profiling latency is in progress...:  37%|███▋      | 37/100 [01:45<02:55,  2.79s/it]
# profiling latency is in progress...:  38%|███▊      | 38/100 [01:48<02:47,  2.71s/it]
# profiling latency is in progress...:  39%|███▉      | 39/100 [01:50<02:42,  2.66s/it]
# profiling latency is in progress...:  40%|████      | 40/100 [01:54<02:55,  2.92s/it]
# profiling latency is in progress...:  41%|████      | 41/100 [01:56<02:48,  2.85s/it]
# profiling latency is in progress...:  42%|████▏     | 42/100 [01:59<02:40,  2.77s/it]
# profiling latency is in progress...:  43%|████▎     | 43/100 [02:01<02:33,  2.70s/it]
# profiling latency is in progress...:  44%|████▍     | 44/100 [02:04<02:35,  2.79s/it]
# profiling latency is in progress...:  45%|████▌     | 45/100 [02:07<02:36,  2.85s/it]
# profiling latency is in progress...:  46%|████▌     | 46/100 [02:10<02:28,  2.76s/it]
# profiling latency is in progress...:  47%|████▋     | 47/100 [02:13<02:22,  2.70s/it]
# profiling latency is in progress...:  48%|████▊     | 48/100 [02:15<02:17,  2.64s/it]
# profiling latency is in progress...:  49%|████▉     | 49/100 [02:19<02:28,  2.91s/it]
# profiling latency is in progress...:  50%|█████     | 50/100 [02:21<02:19,  2.80s/it]
# profiling latency is in progress...:  51%|█████     | 51/100 [02:24<02:13,  2.73s/it]
# profiling latency is in progress...:  52%|█████▏    | 52/100 [02:26<02:08,  2.68s/it]
# profiling latency is in progress...:  53%|█████▎    | 53/100 [02:29<02:05,  2.68s/it]
# profiling latency is in progress...:  54%|█████▍    | 54/100 [02:32<02:12,  2.89s/it]
# profiling latency is in progress...:  55%|█████▌    | 55/100 [02:35<02:05,  2.78s/it]
# profiling latency is in progress...:  56%|█████▌    | 56/100 [02:37<01:58,  2.70s/it]
# profiling latency is in progress...:  57%|█████▋    | 57/100 [02:40<01:53,  2.64s/it]
# profiling latency is in progress...:  58%|█████▊    | 58/100 [02:43<01:57,  2.81s/it]
# profiling latency is in progress...:  59%|█████▉    | 59/100 [02:46<01:54,  2.80s/it]
# profiling latency is in progress...:  60%|██████    | 60/100 [02:48<01:48,  2.72s/it]
# profiling latency is in progress...:  61%|██████    | 61/100 [02:51<01:43,  2.66s/it]
# profiling latency is in progress...:  62%|██████▏   | 62/100 [02:53<01:39,  2.63s/it]
# profiling latency is in progress...:  63%|██████▎   | 63/100 [02:57<01:47,  2.91s/it]
# profiling latency is in progress...:  64%|██████▍   | 64/100 [03:00<01:40,  2.80s/it]
# profiling latency is in progress...:  65%|██████▌   | 65/100 [03:02<01:35,  2.71s/it]
# profiling latency is in progress...:  66%|██████▌   | 66/100 [03:05<01:30,  2.65s/it]
# profiling latency is in progress...:  67%|██████▋   | 67/100 [03:07<01:28,  2.70s/it]
# profiling latency is in progress...:  68%|██████▊   | 68/100 [03:11<01:31,  2.86s/it]
# profiling latency is in progress...:  69%|██████▉   | 69/100 [03:13<01:25,  2.76s/it]
# profiling latency is in progress...:  70%|███████   | 70/100 [03:16<01:20,  2.69s/it]
# profiling latency is in progress...:  71%|███████   | 71/100 [03:18<01:16,  2.65s/it]
# profiling latency is in progress...:  72%|███████▏  | 72/100 [03:22<01:20,  2.86s/it]
# profiling latency is in progress...:  73%|███████▎  | 73/100 [03:24<01:15,  2.81s/it]
# profiling latency is in progress...:  74%|███████▍  | 74/100 [03:27<01:11,  2.73s/it]
# profiling latency is in progress...:  75%|███████▌  | 75/100 [03:29<01:06,  2.66s/it]
# profiling latency is in progress...:  76%|███████▌  | 76/100 [03:32<01:02,  2.62s/it]
# profiling latency is in progress...:  77%|███████▋  | 77/100 [03:35<01:06,  2.90s/it]
# profiling latency is in progress...:  78%|███████▊  | 78/100 [03:38<01:01,  2.79s/it]
# profiling latency is in progress...:  79%|███████▉  | 79/100 [03:40<00:56,  2.71s/it]
# profiling latency is in progress...:  80%|████████  | 80/100 [03:43<00:53,  2.66s/it]
# profiling latency is in progress...:  81%|████████  | 81/100 [03:46<00:51,  2.74s/it]
# profiling latency is in progress...:  82%|████████▏ | 82/100 [03:49<00:51,  2.85s/it]
# profiling latency is in progress...:  83%|████████▎ | 83/100 [03:52<00:46,  2.75s/it]
# profiling latency is in progress...:  84%|████████▍ | 84/100 [03:54<00:42,  2.69s/it]
# profiling latency is in progress...:  85%|████████▌ | 85/100 [03:57<00:39,  2.64s/it]
# profiling latency is in progress...:  86%|████████▌ | 86/100 [04:00<00:40,  2.87s/it]
# profiling latency is in progress...:  87%|████████▋ | 87/100 [04:03<00:36,  2.79s/it]
# profiling latency is in progress...:  88%|████████▊ | 88/100 [04:05<00:32,  2.70s/it]
# profiling latency is in progress...:  89%|████████▉ | 89/100 [04:08<00:29,  2.64s/it]
# profiling latency is in progress...:  90%|█████████ | 90/100 [04:10<00:25,  2.59s/it]
# profiling latency is in progress...:  91%|█████████ | 91/100 [04:14<00:25,  2.86s/it]
# profiling latency is in progress...:  92%|█████████▏| 92/100 [04:16<00:22,  2.76s/it]
# profiling latency is in progress...:  93%|█████████▎| 93/100 [04:19<00:20,  2.89s/it]
# profiling latency is in progress...:  94%|█████████▍| 94/100 [04:22<00:16,  2.78s/it]
# profiling latency is in progress...:  95%|█████████▌| 95/100 [04:25<00:14,  2.97s/it]
# profiling latency is in progress...:  96%|█████████▌| 96/100 [04:28<00:11,  2.89s/it]
# profiling latency is in progress...:  97%|█████████▋| 97/100 [04:30<00:08,  2.77s/it]
# profiling latency is in progress...:  98%|█████████▊| 98/100 [04:33<00:05,  2.69s/it]
# profiling latency is in progress...:  99%|█████████▉| 99/100 [04:36<00:02,  2.68s/it]
# profiling latency is in progress...: 100%|██████████| 100/100 [04:39<00:00,  2.80s/it]
# ViTLarge inference latency: 2796.66 ms

# %% [markdown]
# ## Record the profiled latancy on:
# - CPU AlexNet latency: ## ms
# - CPU ResNet152 latency: ## ms
# - CPU ViT-Large latency: ## ms
# - GPU AlexNet latency: ## ms
# - GPU ResNet152 latency: ## ms
# - GPU ViT-Large latency: ## ms

# %% [markdown]
# Compare your results for the different DNN models you profiles on the different hardware:
#
# Why did you get different latencies for each DNN model?
#
# Why did you get different latencies for different hardware?
